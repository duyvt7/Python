# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv(
    'data/btc-eth-prices-outliers.csv',
    index_col=0,
    parse_dates=True,
)

# %%
df.head()
# Out:
#                 Bitcoin  Ether
# Timestamp
# 2017-04-02  1099.169125  48.55
# 2017-04-03  1141.813000  44.13
# 2017-04-04  1141.600363  44.43
# 2017-04-05  1133.079314  44.90
# 2017-04-06  1196.307937  43.23

# %%
df.plot(figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
df.loc['2017-12':'2017-12-15'].plot(y='Ether', figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
df_na=df.loc['2017-12':'2017-12-15']

# %%
df_na['Ether'].isna().values.any()
# Out:
# True

# %%
df_na.loc[df_na['Ether'].isna()]
# Out:
#                  Bitcoin  Ether
# Timestamp
# 2017-12-08  16007.436667    NaN
# 2017-12-09  15142.834152    NaN
# 2017-12-10  14869.805000    NaN

# %%
df_na.loc['2017-12-06':'2017-12-12']
# Out:
#                  Bitcoin   Ether
# Timestamp
# 2017-12-06  13540.980000  422.48
# 2017-12-07  16501.971667  421.15
# 2017-12-08  16007.436667     NaN
# 2017-12-09  15142.834152     NaN
# 2017-12-10  14869.805000     NaN
# 2017-12-11  16762.116667  513.29
# 2017-12-12  17276.393333  656.52

# %%
df_na.loc['2017-12-06':'2017-12-12'].fillna(method='Bfill')
# Out:
#                  Bitcoin   Ether
# Timestamp
# 2017-12-06  13540.980000  422.48
# 2017-12-07  16501.971667  421.15
# 2017-12-08  16007.436667  513.29
# 2017-12-09  15142.834152  513.29
# 2017-12-10  14869.805000  513.29
# 2017-12-11  16762.116667  513.29
# 2017-12-12  17276.393333  656.52

# %%
df.loc['2017-12-06':'2017-12-12']
# Out:
#                  Bitcoin   Ether
# Timestamp
# 2017-12-06  13540.980000  422.48
# 2017-12-07  16501.971667  421.15
# 2017-12-08  16007.436667     NaN
# 2017-12-09  15142.834152     NaN
# 2017-12-10  14869.805000     NaN
# 2017-12-11  16762.116667  513.29
# 2017-12-12  17276.393333  656.52

# %%
df.fillna(method='bfill', inplace=True)

# %%
df.plot(figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(
    'data/btc-eth-prices-outliers.csv',
    index_col=0,
    parse_dates=True
)

# %%
df
# Out:
#                 Bitcoin   Ether
# Timestamp
# 2017-04-02  1099.169125   48.55
# 2017-04-03  1141.813000   44.13
# 2017-04-04  1141.600363   44.43
# 2017-04-05  1133.079314   44.90
# 2017-04-06  1196.307937   43.23
# ...                 ...     ...
# 2018-03-28  7960.380000  445.93
# 2018-03-29  7172.280000  383.90
# 2018-03-30  6882.531667  393.82
# 2018-03-31  6935.480000  394.07
# 2018-04-01  6794.105000  378.85
#
# [365 rows x 2 columns]

# %%
plt.plot(df)

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
df['Ether'].isna()
# Out:
# Timestamp
# 2017-04-02    False
# 2017-04-03    False
# 2017-04-04    False
# 2017-04-05    False
# 2017-04-06    False
#               ...
# 2018-03-28    False
# 2018-03-29    False
# 2018-03-30    False
# 2018-03-31    False
# 2018-04-01    False
# Name: Ether, Length: 365, dtype: bool

# %%
df.loc['2017-12'].plot(y='Ether', figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
df_na=df.loc['2017-12-06':'2017-12-12']

# %%
df_na
# Out:
#                  Bitcoin   Ether
# Timestamp
# 2017-12-06  13540.980000  422.48
# 2017-12-07  16501.971667  421.15
# 2017-12-08  16007.436667     NaN
# 2017-12-09  15142.834152     NaN
# 2017-12-10  14869.805000     NaN
# 2017-12-11  16762.116667  513.29
# 2017-12-12  17276.393333  656.52

# %%
df_na['Ether'].isna().values.any()
# Out:
# True

# %%
df_na.loc[df_na['Ether'].isna()]
# Out:
#                  Bitcoin  Ether
# Timestamp
# 2017-12-08  16007.436667    NaN
# 2017-12-09  15142.834152    NaN
# 2017-12-10  14869.805000    NaN

# %%
df_na['Ether'].fillna(method='bfill')
# Out:
# Timestamp
# 2017-12-06    422.48
# 2017-12-07    421.15
# 2017-12-08    513.29
# 2017-12-09    513.29
# 2017-12-10    513.29
# 2017-12-11    513.29
# 2017-12-12    656.52
# Name: Ether, dtype: float64

# %%
df_na
# Out:
#                  Bitcoin   Ether
# Timestamp
# 2017-12-06  13540.980000  422.48
# 2017-12-07  16501.971667  421.15
# 2017-12-08  16007.436667     NaN
# 2017-12-09  15142.834152     NaN
# 2017-12-10  14869.805000     NaN
# 2017-12-11  16762.116667  513.29
# 2017-12-12  17276.393333  656.52

# %%
df.fillna(method='bfill', inplace=True)

# %%
df
# Out:
#                 Bitcoin   Ether
# Timestamp
# 2017-04-02  1099.169125   48.55
# 2017-04-03  1141.813000   44.13
# 2017-04-04  1141.600363   44.43
# 2017-04-05  1133.079314   44.90
# 2017-04-06  1196.307937   43.23
# ...                 ...     ...
# 2018-03-28  7960.380000  445.93
# 2018-03-29  7172.280000  383.90
# 2018-03-30  6882.531667  393.82
# 2018-03-31  6935.480000  394.07
# 2018-04-01  6794.105000  378.85
#
# [365 rows x 2 columns]

# %%
df['Ether'].loc['2017-12-06':'2017-12-12']
# Out:
# Timestamp
# 2017-12-06    422.48
# 2017-12-07    421.15
# 2017-12-08    513.29
# 2017-12-09    513.29
# 2017-12-10    513.29
# 2017-12-11    513.29
# 2017-12-12    656.52
# Name: Ether, dtype: float64

# %%
df.plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
df['Ether'].loc['2017-12-25':'2018-01-01'].plot()
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
df_clean=df.drop(pd.to_datetime(['2017-12-28', '2018-03-04']))

# %%
df_clean.plot()
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
df.mean()
# Out:
# Bitcoin    6996.004022
# Ether       469.609068
# dtype: float64

# %%
df_clean.plot(kind='hist', y='Ether', bins=150)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
fig, ax = plt.subplots(figsize=(15,7))
sns.distplot(df_clean['Ether'])
# Out:
# c:\Users\MES PC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Ether', ylabel='Density'>

# %%
fig, ax= plt.subplots(figsize=(15,7))
sns.distplot(df_clean['Ether'], ax=ax)
# Out:
# c:\Users\MES PC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Ether', ylabel='Density'>

# %%
fig, ax = plt.subplots(figsize=(15,7))
sns.distplot(df_clean['Bitcoin'], rug=True, ax=ax)
# Out:
# c:\Users\MES PC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\MES PC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Bitcoin', ylabel='Density'>

# %%
fix, ax =plt.subplots(figsize=(15,7))
sns.kdeplot(df_clean['Ether'], shade=True, cut=0, ax= ax)
sns.rugplot(df_clean['Bitcoin'], ax=ax);

# %%
fig, ax = plt.subplots(figsize=(15, 7))
sns.distplot(df_cleaned['Bitcoin'], ax=ax,
             hist_kws=dict(cumulative=True),
             kde_kws=dict(cumulative=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Duy\DataAnalyst\Python practice\Python\data-cleaning-rmotr-freecodecamp-master\practice.ipynb Cell 40' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Duy/DataAnalyst/Python%20practice/Python/data-cleaning-rmotr-freecodecamp-master/practice.ipynb#ch0000041?line=0'>1</a> fig, ax = plt.subplots(figsize=(15, 7))
# ----> <a href='vscode-notebook-cell:/d%3A/Duy/DataAnalyst/Python%20practice/Python/data-cleaning-rmotr-freecodecamp-master/practice.ipynb#ch0000041?line=1'>2</a> sns.distplot(df_cleaned['Bitcoin'], ax=ax,
#       <a href='vscode-notebook-cell:/d%3A/Duy/DataAnalyst/Python%20practice/Python/data-cleaning-rmotr-freecodecamp-master/practice.ipynb#ch0000041?line=2'>3</a>              hist_kws=dict(cumulative=True),
# ...
